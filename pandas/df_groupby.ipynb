# %% [markdown]
# <a href="https://colab.research.google.com/github/mademet/DAwPY/blob/main/pandas/df_groupby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = sns.load_dataset("flights")
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df.groupby("year").count()
# Out:
#       month  passengers
# year
# 1949     12          12
# 1950     12          12
# 1951     12          12
# 1952     12          12
# 1953     12          12
# 1954     12          12
# 1955     12          12
# 1956     12          12
# 1957     12          12
# 1958     12          12
# 1959     12          12
# 1960     12          12

# %%
df.groupby("year").sum()
# Out:
#       passengers
# year
# 1949        1520
# 1950        1676
# 1951        2042
# 1952        2364
# 1953        2700
# 1954        2867
# 1955        3408
# 1956        3939
# 1957        4421
# 1958        4572
# 1959        5140
# 1960        5714

# %%
df.groupby("year").max()  # returns max passenger in a mounth
# Out:
#       passengers
# year
# 1949         148
# 1950         170
# 1951         199
# 1952         242
# 1953         272
# 1954         302
# 1955         364
# 1956         413
# 1957         467
# 1958         505
# 1959         559
# 1960         622

# %%
planets = sns.load_dataset("planets")

# %%
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
planets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
planets.describe()
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %%
planets.describe(include="all")
# Out:
#                  method       number  ...     distance         year
# count              1035  1035.000000  ...   808.000000  1035.000000
# unique               10          NaN  ...          NaN          NaN
# top     Radial Velocity          NaN  ...          NaN          NaN
# freq                553          NaN  ...          NaN          NaN
# mean                NaN     1.785507  ...   264.069282  2009.070531
# std                 NaN     1.240976  ...   733.116493     3.972567
# min                 NaN     1.000000  ...     1.350000  1989.000000
# 25%                 NaN     1.000000  ...    32.560000  2007.000000
# 50%                 NaN     1.000000  ...    55.250000  2010.000000
# 75%                 NaN     2.000000  ...   178.500000  2012.000000
# max                 NaN     7.000000  ...  8500.000000  2014.000000
#
# [11 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(planets["year"], bins=100);

# %%
planets.dropna()
# Out:
#               method  number  orbital_period    mass  distance  year
# 0    Radial Velocity       1       269.30000   7.100     77.40  2006
# 1    Radial Velocity       1       874.77400   2.210     56.95  2008
# 2    Radial Velocity       1       763.00000   2.600     19.84  2011
# 3    Radial Velocity       1       326.03000  19.400    110.62  2007
# 4    Radial Velocity       1       516.22000  10.500    119.47  2009
# ..               ...     ...             ...     ...       ...   ...
# 640  Radial Velocity       1       111.70000   2.100     14.90  2009
# 641  Radial Velocity       1         5.05050   1.068     44.46  2013
# 642  Radial Velocity       1       311.28800   1.940     17.24  1999
# 649          Transit       1         2.70339   1.470    178.00  2013
# 784  Radial Velocity       3       580.00000   0.947    135.00  2012
#
# [498 rows x 6 columns]

# %%
planets.method
# Out:
# 0       Radial Velocity
# 1       Radial Velocity
# 2       Radial Velocity
# 3       Radial Velocity
# 4       Radial Velocity
#              ...
# 1030            Transit
# 1031            Transit
# 1032            Transit
# 1033            Transit
# 1034            Transit
# Name: method, Length: 1035, dtype: object

# %%
planets.method.describe()
# Out:
# count                1035
# unique                 10
# top       Radial Velocity
# freq                  553
# Name: method, dtype: object

# %%
planets.method.value_counts()
# Out:
# Radial Velocity                  553
# Transit                          397
# Imaging                           38
# Microlensing                      23
# Eclipse Timing Variations          9
# Pulsar Timing                      5
# Transit Timing Variations          4
# Orbital Brightness Modulation      3
# Astrometry                         2
# Pulsation Timing Variations        1
# Name: method, dtype: int64

# %%
planets.method.unique()
# Out:
# array(['Radial Velocity', 'Imaging', 'Eclipse Timing Variations',
#        'Transit', 'Astrometry', 'Transit Timing Variations',
#        'Orbital Brightness Modulation', 'Microlensing', 'Pulsar Timing',
#        'Pulsation Timing Variations'], dtype=object)

# %%
planets.groupby("method").sum()
# Out:
#                                number  orbital_period  ...   distance     year
# method                                                 ...
# Astrometry                          2    1.262360e+03  ...      35.75     4023
# Eclipse Timing Variations          15    4.276480e+04  ...    1261.44    18090
# Imaging                            50    1.418973e+06  ...    2166.91    76347
# Microlensing                       27    2.207500e+04  ...   41440.00    46225
# Orbital Brightness Modulation       5    2.127920e+00  ...    2360.00     6035
# Pulsar Timing                      11    3.671511e+04  ...    1200.00     9992
# Pulsation Timing Variations         1    1.170000e+03  ...       0.00     2007
# Radial Velocity                   952    4.553151e+05  ...   27348.11  1110158
# Transit                           776    8.377523e+03  ...  134242.77   798461
# Transit Timing Variations           9    2.393505e+02  ...    3313.00     8050
#
# [10 rows x 5 columns]

# %%
planets.groupby("method")[["distance"]].mean()
# Out:
#                                   distance
# method
# Astrometry                       17.875000
# Eclipse Timing Variations       315.360000
# Imaging                          67.715937
# Microlensing                   4144.000000
# Orbital Brightness Modulation  1180.000000
# Pulsar Timing                  1200.000000
# Pulsation Timing Variations            NaN
# Radial Velocity                  51.600208
# Transit                         599.298080
# Transit Timing Variations      1104.333333

# %%
planets.groupby(["method", "year"])[["distance", "orbital_period"]].mean()
# Out:
#                                 distance  orbital_period
# method                    year
# Astrometry                2010     14.98     1016.000000
#                           2013     20.77      246.360000
# Eclipse Timing Variations 2008    130.72     4544.000000
#                           2009       NaN    10220.000000
#                           2010    500.00     4228.525000
# ...                                  ...             ...
# Transit                   2014    517.50       18.923712
# Transit Timing Variations 2011   2119.00      160.000000
#                           2012    855.00       57.011000
#                           2013    339.00       22.339500
#                           2014       NaN             NaN
#
# [69 rows x 2 columns]

# %%
planets.groupby("method")[["orbital_period"]].describe()
# Out:
#                               orbital_period  ...
#                                        count  ...            max
# method                                        ...
# Astrometry                               2.0  ...    1016.000000
# Eclipse Timing Variations                9.0  ...   10220.000000
# Imaging                                 12.0  ...  730000.000000
# Microlensing                             7.0  ...    5100.000000
# Orbital Brightness Modulation            3.0  ...       1.544929
# Pulsar Timing                            5.0  ...   36525.000000
# Pulsation Timing Variations              1.0  ...    1170.000000
# Radial Velocity                        553.0  ...   17337.500000
# Transit                                397.0  ...     331.600590
# Transit Timing Variations                3.0  ...     160.000000
#
# [10 rows x 8 columns]

# %%
planets.describe().T
# planets.describe().transpose()
# Out:
#                  count         mean  ...       75%       max
# number          1035.0     1.785507  ...     2.000       7.0
# orbital_period   992.0  2002.917596  ...   526.005  730000.0
# mass             513.0     2.638161  ...     3.040      25.0
# distance         808.0   264.069282  ...   178.500    8500.0
# year            1035.0  2009.070531  ...  2012.000    2014.0
#
# [5 rows x 8 columns]

# %%
df6 = pd.DataFrame({'groups': ['A', 'B', 'C', 'A', 'B', 'C','A', 'B', 'C'],
                   'var1': [10,23,33,22,11,99,40,20,15],
                   'var2': [100,253,333,262,111,969, 232,343,123]})
df6
# Out:
#   groups  var1  var2
# 0      A    10   100
# 1      B    23   253
# 2      C    33   333
# 3      A    22   262
# 4      B    11   111
# 5      C    99   969
# 6      A    40   232
# 7      B    20   343
# 8      C    15   123

# %%
df6.groupby("groups").mean()
# Out:
#         var1        var2
# groups
# A       24.0  198.000000
# B       18.0  235.666667
# C       49.0  475.000000

# %%
def kareal():
    return 3

# %%
df6.groupby("groups").agg({"var1":(np.mean, np.median), "var2":(np.mean, np.median)})
# Out:
#        var1               var2
#        mean median        mean median
# groups
# A        24     22  198.000000    232
# B        18     20  235.666667    253
# C        49     33  475.000000    333

# %%
df6.groupby("groups").filter(lambda x: x["var1"].mean() > 19)
# Out:
#   groups  var1  var2
# 0      A    10   100
# 2      C    33   333
# 3      A    22   262
# 5      C    99   969
# 6      A    40   232
# 8      C    15   123

# %%
df6.groups = df6["groups"].map({"A":"Ahmet", "B": "Mehmet", "C": "Hasan"})
df6
# Out:
#   groups  var1  var2
# 0    NaN    10   100
# 1    NaN    23   253
# 2    NaN    33   333
# 3    NaN    22   262
# 4    NaN    11   111
# 5    NaN    99   969
# 6    NaN    40   232
# 7    NaN    20   343
# 8    NaN    15   123
